# %% [markdown]
# ## Машинное обучение 1, ПМИ ФКН ВШЭ
#
# ## Практическое домашнее задание 1
#
# ### Общая информация
#
# Дата выдачи: 25.09.2024
#
# Мягкий дедлайн: 23:59MSK 06.10.2024
#
# Жесткий дедлайн: 23:59MSK 10.10.2024

# %% [markdown]
# ### О задании
#
# Задание состоит из двух разделов, посвященных работе с табличными данными с помощью библиотеки `pandas` и визуализации с помощью `matplotlib`. В первом разделе вам предстоит выполнить базовые задания с помощью вышеуказанных библиотек, а во втором распределить студентов по курсам. Баллы даются за выполнение отдельных пунктов. Задачи в рамках одного раздела рекомендуется решать в том порядке, в котором они даны в задании.
#
# Задание направлено на освоение jupyter notebook (будет использоваться в дальнейших заданиях), библиотек pandas и matplotlib.
#
# ### Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 10 баллов без учёта бонусов. Сдавать задание после жёсткого дедлайна нельзя.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# ### Формат сдачи
# Задания сдаются через систему Anytask. Инвайт можно получить у семинариста или ассистента. Присылать необходимо ноутбук с выполненным заданием. Сам ноутбук называйте в формате `homework-practice-01-pandas-Username.ipynb`, где Username — ваша фамилия.
#
# Для удобства проверки самостоятельно посчитайте свою максимальную оценку (исходя из набора решенных задач) и укажите ниже.
#
# Оценка: xx.

# %% [markdown]
# ## 0. Введение

# %% [markdown]
# Сейчас мы находимся в jupyter-ноутбуке (или ipython-ноутбуке). Это удобная среда для написания кода, проведения экспериментов, изучения данных, построения визуализаций и других нужд, не связанных с написанием production-кода.
#
# Ноутбук состоит из ячеек, каждая из которых может быть либо ячейкой с кодом, либо ячейкой с текстом размеченным и неразмеченным. Текст поддерживает markdown-разметку и формулы в Latex.
#
# Для работы с содержимым ячейки используется *режим редактирования* (*Edit mode*, включается нажатием клавиши **Enter** после выбора ячейки), а для навигации между ячейками искользуется *командный режим* (*Command mode*, включается нажатием клавиши **Esc**). Тип ячейки можно задать в командном режиме либо с помощью горячих клавиш (**y** to code, **m** to markdown, **r** to edit raw text), либо в меню *Cell -> Cell type*.
#
# После заполнения ячейки нужно нажать *Shift + Enter*, эта команда обработает содержимое ячейки: проинтерпретирует код или сверстает размеченный текст.

# %%
# ячейка с кодом, при выполнении которой появится output
2 + 2
# Out:
# 4

# %% [markdown]
# Ячейка с неразмеченным текстом.

# %% [markdown]
# Попробуйте создать свои ячейки, написать какой-нибудь код и текст какой-нибудь формулой.

# %%
# your code
print("Эшкере")
# Out:
# Эшкере

# %% [markdown]
# [Здесь](https://athena.brynmawr.edu/jupyter/hub/dblank/public/Jupyter%20Notebook%20Users%20Manual.ipynb) находится <s>не</s>большая заметка о используемом языке разметки Markdown. Он позволяет:
#
# 0. Составлять упорядоченные списки
# 1. Выделять *текст* <s>при</s> **необходимости**
# 2. Добавлять [ссылки](http://imgs.xkcd.com/comics/the_universal_label.png)
#
#
# * Составлять неупорядоченные списки
#
# Делать вставки с помощью LaTex:
#
# $
# \left\{
# \begin{array}{ll}
# x = 16 \sin^3 (t) \\
# y = 13 \cos (t) - 5 \cos (2t) - 2 \cos (3t) - \cos (4t) \\
# t \in [0, 2 \pi]
# \end{array}
# \right.$

# %% [markdown]
# А ещё можно вставлять картинки, или гифки, или что захотите:
#
# <img src="https://media1.tenor.com/images/9b8fbe9214504bcf6c60fe4e4f7e114e/tenor.gif?itemid=5416416" style="width: 400px">

# %% [markdown]
# ### Google Colab

# %% [markdown]
# Что за колаб?
#
# **Google Colab (Colaboratory)** это **Jupyter Notebook + Cloud + Google Drive.**
#
# Компания Google предоставляет возможность бесплатно запускать ноутбуки (предварительно загрузив их на свой гугл-диск) прямо в облаке. При этом вам не требуется установка никаких пакетов на свою машину, а работать можно прямиком из браузера. Вот ссылка:

# %% [markdown]
# https://colab.research.google.com

# %% [markdown]
# При использовании вы увидите много сходств с jupyter ноутбуком. Одним из преимуществ является доступность GPU, соответствующую опцию можно активировать в настройках сервиса. При желании вы сможете найти в интернете много туториалов по использованию или разобраться самостоятельно

# %% [markdown]
# ### Kaggle
#
# Альтернативой является **Kaggle**, он же площадка для самых разных соревнований по машинному обучению
#
# Он, как и колаб, предоставляет бесплатный GPU, и даже не один, с чётким лимитом в 30 часов в неделю (colab может его внезапно отобрать, kaggle - нет) более мощные CPU с большим числом ядер, и больше Гб ОЗУ (раз так в 2.5)
#
# https://www.kaggle.com
#
# К сожалению мир не идеален, недостатки следующие:
# - необходимость загружать датасеты через специальную кнопочку
# - невозможность использовать свои скрипты и модули :(
# - нужно тыкать техподдержку, чтобы создать аккаунт из России

# %% [markdown]
# ## 1. Табличные данные и Pandas

# %% [markdown]
# Pandas — удобная библиотека для работы с табличными данными в Python, если данных не слишком много и они помещаются в оперативную память вашего компьютера. Несмотря на неэффективность реализации и некоторые проблемы, библиотека стала стандартом в анализе данных.
#
# Основной объект в `pandas` — это `pd.DataFrame`, представляющий собой таблицу с именованными колонками различных типов, индексом (может быть многоуровневым). DataFrame можно создавать, считывая таблицу из файла или задавая вручную из других объектов.
#
# В этой части потребуется выполнить несколько небольших заданий. Можно пойти двумя путями: сначала изучить материалы, а потом приступить к заданиям, или же разбираться "по ходу". Выбирайте сами.
#
# Материалы:
# 1. [Pandas за 10 минут из официального руководства](http://pandas.pydata.org/pandas-docs/stable/10min.html)
# 2. [Документация](http://pandas.pydata.org/pandas-docs/stable/index.html) (стоит обращаться, если не понятно, как вызывать конкретный метод)
# 3. [Примеры использования функционала](http://nbviewer.jupyter.org/github/justmarkham/pandas-videos/blob/master/pandas.ipynb)
#
# Многие из заданий можно выполнить несколькими способами. Не существуют единственно верного, но попробуйте максимально задействовать арсенал pandas и ориентируйтесь на простоту и понятность вашего кода. Мы не будем подсказывать, что нужно использовать для решения конкретной задачи, попробуйте находить необходимый функционал сами (название метода чаще всего очевидно). В помощь вам документация, поиск и StackOverflow.

# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# <span style="color:red">Перед выполнением задания необходимо ознакомиться с первым семинаром (seminars/sem01-pandas.ipynb) </span>.
#
# Это поможет вам получить общее понимание происходяшего и успешнее справиться с заданием.
#
# Также успешному выполнению способствует внимательное чтение текста задания от начала до конца.
#
# Удачи!

# %% [markdown]
# Скачаем подготовленные на семинаре данные:

# %%
# !wget  -O 'end_seminar.xlsx' -q 'https://www.dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=0'

# %% [markdown]
# Для пользователей Windows: скачайте файл самостоятельно и поместите его в папку с тетрадкой. Или попробуйте один из следующих вариантов:

# %%
# !powershell iwr -outf somefile https://somesite/somefile

# %%
# !pip install wget
# import wget
# wget.download('https://dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=1', 'end_seminar.xlsx')

# %% [markdown]
# ##### В первой части задания (до раздела "Распределение студентов по курсам") использование циклов запрещается и повлечет за собой снижение оценки. Использование <code>vectorize</code> и  <code>apply</code>, <code>apply_along_axis</code> и всего, где можно применить лямбда-функции (`assign`, `map`, ...) крайне нежелательно

# %% [markdown]
# Для каждой задачи из этого раздела вы должны написать код для получения ответа, а также дать текстовый ответ, если он предполагается.
#
# На некоторые вопросы вы можете получить путём пристального взгляда на таблицу, но это не будет засчитываться. Вы в любом случае должны получить ответ с помощью кода.

# %% [markdown]
# #### 1. [0.5 баллов] Откройте файл с таблицей (не забудьте про её формат). Выведите 3 последних строки.
#
# Посмотрите на данные и скажите, что они из себя представляют, сколько в таблице строк, какие столбцы? (на это не надо отвечать, просто подумайте об этом)

# %%
# your code
data_3 = pd.read_excel("end_seminar.xlsx")
data_3
# Out:
#                   timestamp                                id  rating  \
# 0   2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503     698
# 1   2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb     647
# 2   2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd     624
# 3   2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68     579
# 4   2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5     572
# ..                      ...                               ...     ...
# 356 2020-05-19 19:04:17.873  c5870b37ee3f672e4259dfb2fc02ed8f    1029
# 357 2020-05-19 20:19:25.815  f44aea1095f9f5b8e2f5f0ed2b17891b    1060
# 358 2020-05-20 11:54:38.318  d7118b44c7e8fdbbaaca226d2da6fef1    1111
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 360 2020-05-23 21:16:40.916  f2d210ace25a841e1e58036b257d5d47    1195
#
#      18_group  is_mi                                           fall_1  \
# ...

# %%
data_3.loc[360:358:-1]
# Out:
#                   timestamp                                id  rating  \
# 360 2020-05-23 21:16:40.916  f2d210ace25a841e1e58036b257d5d47    1195
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 358 2020-05-20 11:54:38.318  d7118b44c7e8fdbbaaca226d2da6fef1    1111
#
#      18_group  is_mi                                           fall_1  \
# 360       NaN    NaN                Анализ неструктурированных данных
# 359       NaN    NaN                 Безопасность компьютерных систем
# 358       NaN    NaN  Сбор и обработка данных с помощью краудсорсинга
#
#                                                 fall_2  \
# 360                      Моделирование временных рядов
# 359  Принятие решений в условиях риска и неопределё...
# 358                        Statistical Learning Theory
#
#                                 fall_3  \
# 360  Высокопроизводительные вычисления
# 359  Анализ неструктурированных данных
# 358  Анализ неструктурированных данных
#
# ...

# %%
data_3.shape
# Out:
# (361, 16)

# %% [markdown]
# ### Ответьте на вопросы:
# 1. Сколько было уникальных пользователей из групп 18-го года набора, а сколько из групп 17-го года?

# %%
# your code
data_18_group = data_3[data_3['18_group'].isna() == False].drop_duplicates(subset='id')
qua = data_18_group.shape[0]
print(qua, "уникальных пользователей в группе 18-го года набора")
data_17_group = data_3[data_3['17_group'].isna() == False].drop_duplicates(subset='id')
qua_2 = data_17_group.shape[0]
print(qua_2, "уникальных пользователей в группе 17-го года набора")
# Out:
# 213 уникальных пользователей в группе 18-го года набора
# 134 уникальных пользователей в группе 17-го года набора

# %% [markdown]
# 2. Есть ли уникальные студенты с равными перцентилями?

# %%
# your code
a = data_3["percentile"].nunique()
b = data_3["id"].nunique()
print(a, b)
# Out:
# 346 347

# %% [markdown]
# То есть у нас 346 студентов с уникальными персентилями и 347 строчек с уникальными id. Всего студентов в датафрейме 361, а значит среди строк с уникальными id должны быть уникальные персентили.
# Ответ: да

# %% [markdown]
# #### 2. [0.5 балла] Есть ли в данных пропуски? В каких колонках? Сколько их в каждой из этих колонок?

# %%
# your code
data_3.isnull().sum()
# Out:
# timestamp          0
# id                 0
# rating             0
# 18_group         138
# is_mi            343
# fall_1             0
# fall_2             0
# fall_3             0
# spring_1           0
# spring_2           0
# spring_3           0
# is_first_time      2
# percentile         0
# 17_group         223
# blended          223
# is_ml_student    304
# dtype: int64

# %%
data_3.dtypes
# Out:
# timestamp        datetime64[ns]
# id                       object
# rating                    int64
# 18_group                float64
# is_mi                   float64
# fall_1                   object
# fall_2                   object
# fall_3                   object
# spring_1                 object
# spring_2                 object
# spring_3                 object
# is_first_time            object
# percentile              float64
# 17_group                float64
# blended                  object
# is_ml_student           float64
# dtype: object

# %% [markdown]
# Заполните пропуски пустой строкой для строковых колонок, нулём для числовых и False для булевых (постарайтесь избежать перечисления названий всех столбцов).

# %% [markdown]
# В датасете нет булевых значений, есть колонки, такие как, is_mi, смысл которых показать "да" или "нет", но они задаются числовым образом, поэтому я заполнила пропуски нулями вместо False

# %%
# your code
values = {"18_group": 0, "is_mi": 0, "is_first_time": "", "17_group": 0, "blended": "", "is_ml_student": 0}
data_3 = data_3.fillna(value=values)
data_3.sample(10)
# Out:
#                   timestamp                                id  rating  \
# 132 2020-05-18 21:15:01.777  f0db08ec702a03450390efdca4166cc2     603
# 158 2020-05-18 21:59:48.193  723d5f32b699c971b4095a017c883ffa     759
# 223 2020-05-14 20:23:21.662  d555d2805e1d93d4f023e57dc4c8f403     996
# 231 2020-05-14 21:52:43.844  3a7326c9e355a67d3805824ca34c4bc5    1457
# 142 2020-05-18 21:35:05.042  a69948a1730e412eab71a4d4e70791e2     663
# 241 2020-05-15 13:37:30.790  ea682b140a15d40156a00aaf0234a91e    1172
# 145 2020-05-18 21:38:00.271  b3e75ee2a708cef65cc2f80da894dd50     560
# 107 2020-05-18 19:34:58.494  8c191b9ac692c190f54e66167b0adc3e     620
# 95  2020-05-18 18:29:57.440  88ae08d9db8d34b267780ed642d0d2db     581
# 186 2020-05-18 23:20:28.235  86c24daaa62246142d46ee58534a65e0     530
#
#      18_group  is_mi                             fall_1  \
# 132     185.0    0.0                           Язык SQL
# 158     184.0    0.0        Statistical Learning Theory
# ...

# %% [markdown]
# #### 3. [0.5 балла] Посмотрите повнимательнее на колонку 'is_first_time'.
#
# Каково процентное соотношение ответов? Сколько из них "Нет"?

# %%
# your code
data_3['is_first_time'].value_counts()
# Out:
# is_first_time
# Да     308
# Нет     51
#          2
# Name: count, dtype: int64

# %%
data_3['is_first_time'].value_counts(normalize=True)
# Out:
# is_first_time
# Да     0.853186
# Нет    0.141274
#        0.005540
# Name: proportion, dtype: float64

# %% [markdown]
# Если вы найдете повторные обращения студентов, оставьте только самую позднюю версию. В дальнейших заданиях используйте версию данных без повторов.
#
# <i>Обращения со значением "Нет" в 'is_first_time' могут быть как повторными, так и первичными, поскольку поле заполняли сами студенты.</i>

# %%
# your code
data_3 = data_3.drop_duplicates(subset = 'id', keep='last')
data_3
# Out:
#                   timestamp                                id  rating  \
# 0   2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503     698
# 1   2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb     647
# 2   2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd     624
# 3   2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68     579
# 4   2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5     572
# ..                      ...                               ...     ...
# 356 2020-05-19 19:04:17.873  c5870b37ee3f672e4259dfb2fc02ed8f    1029
# 357 2020-05-19 20:19:25.815  f44aea1095f9f5b8e2f5f0ed2b17891b    1060
# 358 2020-05-20 11:54:38.318  d7118b44c7e8fdbbaaca226d2da6fef1    1111
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 360 2020-05-23 21:16:40.916  f2d210ace25a841e1e58036b257d5d47    1195
#
#      18_group  is_mi                                           fall_1  \
# ...

# %% [markdown]
# #### 4. [0.5 балла] Какие  blended-курсы для четверокурсников существуют? На какой blended-курс записалось наибольшее количество студентов? На каком из blended-курсов собрались студенты с самым высоким средним рейтингом (выведите этот курс и количество студентов на нем)?

# %%
# your code
data_3_filtered = data_3.loc[data_3['17_group'] != 0, 'blended']
print("Курсы, доступные 4-курсникам:", data_3_filtered.unique())
# Out:
# Курсы, доступные 4-курсникам: ['DevOps' 'Введение в дифференциальную геометрию'
#  'Соревновательный анализ данных']

# %%
data_3_filtered.describe()
# Out:
# count        134
# unique         3
# top       DevOps
# freq          87
# Name: blended, dtype: object

# %% [markdown]
# Соответсвенно: самый популярный курс - DevOps

# %%
data_3_filter = data_3.loc[data_3['17_group']  != 0]

data_3_filter.groupby('blended').agg(
    mean_rating=('rating', 'mean'),
    students= ('id','count'))
# Out:
#                                        mean_rating  students
# blended
# DevOps                                 1154.172414        87
# Введение в дифференциальную геометрию  1210.733333        15
# Соревновательный анализ данных         1144.218750        32

# %% [markdown]
# #### 5. [1 балл] Выясните, есть ли студенты с абсолютно одинаковыми предпочтениями по всем курсам.
#
# Для этого сформируйте таблицу, где для каждого возможного набора курсов посчитано количество студентов, выбравших такой набор, и оставьте только строки где это количество больше 1.
#
# В данном случае набор курсов задается упорядоченным множеством ('fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended'). Элемент blended будет нулевым для 3-го курса.

# %%
# your code
cr = data_3.groupby(['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended']).agg(qua_of_students = ('id', 'count'))
cr.loc[cr['qua_of_students'] > 1]
# Out:
#                                                                                                                                                                                                                                                                                                     qua_of_students
# fall_1                                          fall_2                                          fall_3                                          spring_1                                           spring_2                                    spring_3                                    blended
# Statistical Learning Theory                     Анализ неструктурированных данных               Сбор и обработка данных с помощью краудсорсинга Обучение с подкреплением                           Конфликты и кооперация                      Компьютерное зрение                         DevOps                 2
# ...

# %% [markdown]
# Из таблицы видно, что студенты с одинаковыми предпочтениями по курсам существуют

# %% [markdown]
# #### 6. [0.5 балла] Найдите курсы по выбору, на которые записывались как студенты 18-го года набора, так и студенты 17-го года.

# %%
# your code
course_3 = pd.Series(data_3.loc[data_3['17_group'] != 0][['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended']].values.ravel()).unique()
course_4 = pd.Series(data_3.loc[data_3['18_group'] != 0][['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended']].values.ravel()).unique()
common_course = set(course_3) & set(course_4)
print(common_course)
# Out:
# {'Высокопроизводительные вычисления', 'Моделирование временных рядов', 'Численные методы', 'Сбор и обработка данных с помощью краудсорсинга', 'Безопасность компьютерных систем', 'Принятие решений в условиях риска и неопределённости', 'Statistical Learning Theory'}

# %% [markdown]
# Методом исключения найдите курсы, которые предлагались только студентам 18-го года и только студентам 17-го года.

# %%
# your code
all_courses = set()
all_courses = all_courses.union(all_courses, course_3, course_4)
sim_dif = all_courses ^ common_course
print(sim_dif)
# Out:
# {'', 'Промышленное программирование на языке Java', 'Проектирование и разработка высоконагруженных сервисов', 'Анализ неструктурированных данных', 'Язык SQL', 'Дополнительные главы прикладной статистики', 'DevOps', 'Конфликты и кооперация', 'Символьные вычисления', 'Соревновательный анализ данных', 'Генеративные модели в машинном обучении', 'Дискретная оптимизация', 'Глубинное обучение в обработке звука', 'Матричные вычисления', 'Компьютерные сети', 'Машинное обучение 2', 'Компьютерное зрение', 'Обучение с подкреплением', 'Введение в дифференциальную геометрию', 'Теория баз данных', 'Байесовские методы машинного обучения', 'Методы сжатия и передачи медиаданных', 'Системы баз данных', 'Анализ данных в бизнесе'}

# %% [markdown]
# Таким образом:
#
# Общие курсы: 'Моделирование временных рядов', 'Высокопроизводительные вычисления', 'Сбор и обработка данных с помощью краудсорсинга', 'Безопасность компьютерных систем', 'Statistical Learning Theory', 'Принятие решений в условиях риска и неопределённости', 'Численные методы'
#
# Различные курсы: 'Теория баз данных', 'Проектирование и разработка высоконагруженных сервисов', 'Анализ данных в бизнесе', 'Системы баз данных', 'Обучение с подкреплением', 'DevOps', 'Дополнительные главы прикладной статистики', 'Генеративные модели в машинном обучении', 'Введение в дифференциальную геометрию', 'Конфликты и кооперация', 'Машинное обучение 2', 'Анализ неструктурированных данных', 'Язык SQL', 'Соревновательный анализ данных', 'Байесовские методы машинного обучения', 'Промышленное программирование на языке Java', 'Компьютерное зрение', 'Символьные вычисления', 'Компьютерные сети', 'Матричные вычисления', 'Глубинное обучение в обработке звука', 'Дискретная оптимизация', 'Методы сжатия и передачи медиаданных'

# %% [markdown]
# ### Визуализации и matplotlib

# %% [markdown]
# При работе с данными часто неудобно делать какие-то выводы, если смотреть на таблицу и числа в частности, поэтому важно уметь визуализировать данные. Здесь будут описаны ключевые правила оформления графиков для **всех** домашних заданий.
#
# У matplotlib, конечно же, есть [документация](https://matplotlib.org/users/index.html) с большим количеством [примеров](https://matplotlib.org/examples/), но для начала достаточно знать про несколько основных типов графиков:
# - plot — обычный поточечный график, которым можно изображать кривые или отдельные точки;
# - hist — гистограмма, показывающая распределение некоторой величины;
# - scatter — график, показывающий взаимосвязь двух величин;
# - bar — столбцовый график, показывающий взаимосвязь количественной величины от категориальной.
#
# В этом задании вы попробуете построить один из них. Не забывайте про базовые принципы построения приличных графиков:
# - оси должны быть подписаны, причём не слишком мелко;
# - у графика должно быть название;
# - если изображено несколько графиков, то необходима поясняющая легенда;
# - все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном);
# - если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах);
# - сетка на графике помогает оценить значения в точках на глаз, это обычно полезно, поэтому лучше ее отрисовывать;
# - если распределение на гистограмме имеет тяжёлые хвосты, лучше использовать логарифмическую шкалу.
#
# Еще одна билиотека для визуализации: [seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html) (обычно сокращается до sns). Это настройка над matplotlib, иногда удобнее и красивее делать визуализации через неё.
#
# **5 пунктов после которых ваши графики не будут прежними:**
# - для красивой картинки <code>%config InlineBackend.figure_format = 'retina'</code>
# - задаем размер (почти) всех графиков (можно выбрать другие значения) <code>plt.rcParams['figure.figsize'] = 8, 5</code>
# - размер шрифта подписей графиков <code>plt.rcParams['font.size'] = 12</code>
# - формат в котором сохраняется изображение <code>mpl.rcParams['savefig.format'] = 'pdf'</code>
# - sns – seaborn, добавляет решетку <code>sns.set_style('darkgrid')</code>
#
# Добавьте эти функции в ячейку ниже. Каждый график все равно придется настраивать отдельно, но указанные строчки позволят значительно упростить процесс.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# your code

# %% [markdown]
# #### 7. [0.5 балла] Постройте график средних рейтингов по дням получения ответов (bar plot).

# %%
# your code

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = 8, 5

avg_ratings_per_day = data_3.groupby(data_3['timestamp'].dt.day)['rating'].mean()

plt.bar(avg_ratings_per_day.index, avg_ratings_per_day.values)
plt.xlabel('День', fontsize=16)
plt.ylabel('Средний рейтинг', fontsize=12)
plt.title('Средние рейтинги по дням получения ответов')
plt.show()

# %% [markdown]
# Сохраните график в формате pdf (так он останется векторизованным).

# %%
# your code
mpl.rcParams['savefig.format'] = 'pdf'

# %% [markdown]
# ### 2. Распределение студентов по курсам.

# %% [markdown]
# <span style="color:red">!!!ВНИМАТЕЛЬНО ИЗУЧИТЕ ТЕКСТ НИЖЕ!!!</span>.
#
# <span style="color:orange">Если во время выполнения заданий у вас вознинут вопросы -- еще раз перечитайте текст целиком, скорее всего ответы уже содержатся в нем.</span>

# %% [markdown]
# Теперь вам нужно распределить студентов по осенним курсам по выбору, учитывая их предпочтения.

# %% [markdown]
# ## 📌 **Алгоритм распределения студентов по курсам**:
# 1. По умолчанию на каждой дисциплине по выбору у 3 и 4 курсов может учиться 1 группа (до 30 студентов). Исключения описаны ниже. На blended-дисциплинах для четверокурсников количество мест не ограничено.
# 2. Проводится первая волна отбора. Для каждой дисциплины формируется список тех, кто указал её первым приоритетом (если студент должен выбрать два курса по выбору, то для него дисциплины, которые он указал первым и вторым приоритетом, рассматриваются как дисциплины первого приоритета). Если желающих больше, чем мест, то выбирается топ по перцентилю рейтинга.
# 3. На дисциплинах, где остались места после первой волны, формируются списки тех, кто выбрал их вторым приоритетом, и места заполняются лучшими по перцентили рейтинга студентами. После этого проводится такая же процедура для дисциплин третьего приоритета.
# 4. Если студент не попал на необходимое количество курсов по итогам трёх волн, с ним связывается учебный офис и решает вопрос в индивидуальном порядке.

# %% [markdown]
# ## ☝️ **Обращаем ваше внимание на следующие детали:**
# - Конкурс на каждый курс общий для 3-го и 4-го курса
#
# - По умолчанию студент выбирает один осенний и один весенний курс по выбору, а также четверокурсники выбирают один blended-курс. Студенты групп 17-го года специализаций МОП и ТИ выбирают по 2 осенних и 2 весенних курса по выбору, также студенты групп 18' специализации МИ выбирают 2 осенних курса. <i>Для студентов, которые выбирают 2 курса (например, осенних) первый приоритет — <code>fall_1</code> и <code>fall_2</code>, второй приоритет — <code>fall_3</code>. Такие студенты участвуют только в двух волнах отбора</i>.
#
# - Студенты специализации МОП не могут выбрать весенним курсом по выбору Машинное обучение 2. **Если студент специализации МОП выбрал Машинное обучение 2, то его приоритеты сдвигаются.** Из-за совпадений первого и второго курса по выбору двигать приоритеты не надо.
#
# - Blended-курсы не трогайте, по ним не надо распределять, на другие курсы они никак не влияют.
#
# - Заведомо известно, что в процессе распределения не возникнет ситуации, когда на одно место претендуют студенты с одинаковым перцентилем.
#
# - Постарайтесь воздержаться от использования циклов там, где это возможно. <i>Допустимо итерироваться по <b>курсам</b>, на которые проводится отбор, и по <b>волнам</b> отбора. Если вы придумаете, как обойтись и без этих циклов, то на усмотрение проверяющего могут быть добавлены бонусные баллы. <b>Дублирование кода не признается успешным избавлением от циклов</b></i>
#
# - На выходе ожидается файл res_fall.csv с результатами распределения на осенние курсы по выбору. Файл должен быть следующего формата:
#
#     * Три колонки: ID, course1, course2
#
#     * Если студент не попал на курс, но должен был, то вместо названия курса в ячейке должна быть строка "???"
#
#     * Если студент должен выбрать только один курс, то в колонке course2 для него должна стоять строка "-"
#
#     * Если студент должен выбрать два курса по выбору, то порядок в колонках course1 и course2 не важен.
#
#     * hint: для сохранения воспользуйтесь `df.to_csv('solution.csv', index=None)`
#
#
# Для работы вам могут понадобиться следующие данные:
#
# - Результаты опроса (вы уже использовали этот файл в первой части задания, но на всякий случай ссылка: https://www.dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=0)
#
# - Соответствие номеров групп специализациям:
#
#     * 171, 172 - МОП; 173 - ТИ; 174 — АДИС; 175, 176 — РС; 177 — АПР
#
#     * У студентов 18-го года номера групп соответствуют номерам до распределения по специализациям. Это означает, что по номеру группы 18* нельзя однозначно определить специализацию студента. При этом в рамках распределения важно знать информацию только о двух из них: МОП и МИ. Эти знание можно получить из колонок 'is_ml_student
# ' и 'is_mi' соответственно.
#
# - Ограничения по количеству мест на курсах по выбору:
#
#     * Осенние: везде 30 мест, кроме Statistical Learning Theory (60 мест), Высокопроизводительных вычислений (60 мест), Анализа неструктурированных данных ($\infty$ мест)
#
#     * Весенние: везде 30 мест, кроме Обучения с подкреплением (60 мест), Анализа данных в бизнесе (60 мест).
#
#
# Кстати, убедитесь, что в данных больше нет пропусков и повторных записей.

# %% [markdown]
# #### 0. Проверка
#
# Для начала давайте убедимся, что вы успешно выполнили задания первой части и проверим ваши данные на наличие пропусков и повторов:

# %%
assert data_3.shape[0] == 347, 'В таблице остались повторы или потеряны данные'

assert data_3.isna().sum().sum() == 0, 'В таблице остались пропуски'

# %%
df = data_3

# %% [markdown]
# Если вы не получили AssertionError, то можете продолжать.

# %% [markdown]
# #### 1. [1 балл] Создайте новый признак, обозначающий, сколько осенних курсов должен выбрать студент
#
# В этом вам может помочь информация о специализации и группе стундента.

# %%
def fall(student):
  if student['17_group'] == 171 or student['17_group'] == 172 or student['17_group'] == 173:
    return 2
  elif student['18_group'] != 0 and student['is_mi'] == 1:
    return 2
  else:
    return 1
df['Number_of_fall_courses'] = df.apply(fall, axis=1)

# %% [markdown]
# Проверка:

# %%
col_name = 'Number_of_fall_courses'    # insert your new column name as str

assert(df[df['id'] == '2662600c2c37e11e62f6ee0b88452f22'][col_name] == 2).all()
assert(df[df['id'] == 'd555d2805e1d93d4f023e57dc4c8f403'][col_name] == 2).all()
assert(df[df['id'] == '8fe79f84f36e3a5d2d6745621321302c'][col_name] == 1).all()
assert(df[df['id'] == 'e4caca755ee0bdd711e18fb8084958b5'][col_name] == 1).all()

# %% [markdown]
# #### 2. [2 балла] Распределите студентов в соответствии с первым приоритетом

# %%
wave_1 = pd.DataFrame(columns=['id', 'course1', 'course2'])

# %%
wave_1['id'] = df['id']
wave_1['course1'] = ''
wave_1['course2'] = ''
wave_1
# Out:
#                                    id course1 course2
# 0    93ff79a51cd602f1dd3028ba2c129503
# 1    26b01b1c4cd5656bab18d24c548834fb
# 2    30f3653fc176d54e89ac3179c455c6dd
# 3    1528f0eaa027580820ccf0d92a53ad68
# 4    496ea4f0d4abe264b1bb1b80eb3830c5
# ..                                ...     ...     ...
# 356  c5870b37ee3f672e4259dfb2fc02ed8f
# 357  f44aea1095f9f5b8e2f5f0ed2b17891b
# 358  d7118b44c7e8fdbbaaca226d2da6fef1
# 359  79d14db48e4737af731960ae212d5134
# 360  f2d210ace25a841e1e58036b257d5d47
#
# [347 rows x 3 columns]

# %%
# (￣^￣)ゞ Отбираем курсы, на которые могут попасть студенты
df = df.sort_values('percentile')
list_of_courses = df['fall_1'].tolist()
list_of_courses = df['fall_2'].tolist()
list_of_courses = list(set(list_of_courses))
list_of_courses
# Out:
# ['Матричные вычисления',
#  'Высокопроизводительные вычисления',
#  'Моделирование временных рядов',
#  'Язык SQL',
#  'Анализ неструктурированных данных',
#  'Сбор и обработка данных с помощью краудсорсинга',
#  'Безопасность компьютерных систем',
#  'Принятие решений в условиях риска и неопределённости',
#  'Теория баз данных',
#  'Байесовские методы машинного обучения',
#  'Statistical Learning Theory',
#  'Глубинное обучение в обработке звука']

# %%
#Функция для заполнения массива свободных мест по каждому курсу
def places(list_of_courses, list_of_places):
  for i in list_of_courses:
    if i == 'Statistical Learning Theory' or i == 'Высокопроизводительные вычисления':
      list_of_places.append(60)
    elif i == 'Анализ неструктурированных данных':
      list_of_places.append(-1)
    else:
      list_of_places.append(30)
  return list_of_places

# %%
list_of_places = []
list_of_places = places(list_of_courses, list_of_places)
for i in range(len(list_of_courses)):
  print(list_of_courses[i], list_of_places[i])
# Out:
# Матричные вычисления 30
# Высокопроизводительные вычисления 60
# Моделирование временных рядов 30
# Язык SQL 30
# Анализ неструктурированных данных -1
# Сбор и обработка данных с помощью краудсорсинга 30
# Безопасность компьютерных систем 30
# Принятие решений в условиях риска и неопределённости 30
# Теория баз данных 30
# Байесовские методы машинного обучения 30
# Statistical Learning Theory 60
# Глубинное обучение в обработке звука 30

# %% [markdown]
# Идея, по которой реализованы все волны: я итерируюсь по массиву курсов, каждый раз создаю датафрейм, в который заношу студентов, желающих попасть на i-й курс и подходщих под условия кпв для разных групп. Затем сортирую их по персентилю (вообще это как будто лишнее, так как я до этого сортировала df, но на всякий случай) и оставляю срез из тех, на кого хватит мест. Добавляю этих людей в итоговый датафрейм, уменьшаю количество мест на курсе и иду дальше.

# %%
for i in range(0, len(list_of_courses)):
  participants = pd.DataFrame(columns=["ID", 'percentile', 'course1'])
  participants['ID'] = df.loc[(df['fall_1'] == list_of_courses[i]) | ((df['17_group'].isin([171, 172, 173])) & (df['fall_2'] == list_of_courses[i]))
   | ((df['is_mi'] == 1) & (df['fall_2'] == list_of_courses[i]))]['id']
  participants['percentile'] = df.loc[(df['fall_1'] == list_of_courses[i]) | ((df['17_group'].isin([171, 172, 173])) & (df['fall_2'] == list_of_courses[i]))
   | ((df['is_mi'] == 1) & (df['fall_2'] == list_of_courses[i]))]['percentile']
  subject = list_of_courses[i]
  participants['course1'] = subject
  participants.drop_duplicates()
  participants.sort_values('percentile') #НА ВСЯКИЙ СЛУЧАЙ от греха подальше
  if list_of_places[i] != -1:

    participants = participants.iloc[:list_of_places[i]]
    num = len(participants)
    wave_1.loc[(wave_1['id'].isin(participants['ID'])) & (wave_1['course1'] != ('')) & (wave_1['course1'] != list_of_courses[i]), 'course2'] = participants['course1']
    wave_1.loc[(wave_1['id'].isin(participants['ID'])) & (wave_1['course1'] == ('')), 'course1'] = participants['course1']

    list_of_places[i] -= num
  elif list_of_places[i] == -1:
    wave_1.loc[(wave_1['id'].isin(participants['ID'])) & (wave_1['course1'] != ('')) & (wave_1['course1'] != list_of_courses[i]), 'course2'] = participants['course1']
    wave_1.loc[(wave_1['id'].isin(participants['ID'])) & (wave_1['course1'] == ('')), 'course1'] = participants['course1']

wave_1.loc[wave_1['course1'] != '']
# Out:
#                                    id  \
# 0    93ff79a51cd602f1dd3028ba2c129503
# 1    26b01b1c4cd5656bab18d24c548834fb
# 3    1528f0eaa027580820ccf0d92a53ad68
# 4    496ea4f0d4abe264b1bb1b80eb3830c5
# 5    d0d8ff53ed5b119f9056068e954256c6
# ..                                ...
# 356  c5870b37ee3f672e4259dfb2fc02ed8f
# 357  f44aea1095f9f5b8e2f5f0ed2b17891b
# 358  d7118b44c7e8fdbbaaca226d2da6fef1
# 359  79d14db48e4737af731960ae212d5134
# 360  f2d210ace25a841e1e58036b257d5d47
#
#                                                course1 course2
# 0                                             Язык SQL
# 1                    Высокопроизводительные вычисления
# 3                          Statistical Learning Theory
# 4                    Высокопроизводительные вычисления
# 5                                             Язык SQL
# ..                                                 ...     ...
# 356                        Statistical Learning Theory
# ...

# %% [markdown]
# Сказали можно не запускать проверку...

# %% [markdown]
# Здесь для проверки приведена таблица, в которой есть 2 дополнительные колонки:
#
#     1) is_first_place - является ли студент лучшим по перцентили хотя бы на одном из курсов, куда он был зачислен
#     (True / NaN)
#
#     2) is_last_place  - является ли студент худшим по перцентили хотя бы на одном из курсов, куда он был зачислен (True / NaN)

# %%
# !wget  -O '2_task_check.csv' -q 'https://www.dropbox.com/s/v8o2zzq3iz5gc9w/_2_task_check.csv?dl=0'
check_df = pd.read_csv('2_task_check.csv')

# %% [markdown]
# После распределения студентов в соответствии с первым приоритетом добавьте в свой датафрейм аналогичные признаки и запустите проверку:

# %%
fir_col_name =   # insert name of your new column with is_first_place as str
last_col_name =     # insert name of your new column with is_last_place as str


assert((df[df[fir_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
        ==
        check_df[check_df['is_first_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       ).id.values).all()


assert((df[df[last_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       ==
       check_df[check_df['is_last_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
      ).id.values).all()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'course1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-154-4e38c91969d6> in <cell line: 5>()
#       3
#       4
# ...

# %% [markdown]
# #### 3. [2 балла] Проведите все три волны отбора студентов на курсы по выбору

# %%
# (￣^￣)ゞ
res_fall = pd.DataFrame(columns=['ID', 'course1', 'course2'])

# %%
res_fall['ID'] = df['id']
res_fall['course1'] = ''
res_fall['course2'] = ''

# %%
df = df.sort_values('percentile')
list_of_courses = df['fall_1'].tolist()
list_of_courses = df['fall_2'].tolist()
list_of_courses = list(set(list_of_courses))
list_of_courses
# Out:
# ['Матричные вычисления',
#  'Высокопроизводительные вычисления',
#  'Моделирование временных рядов',
#  'Язык SQL',
#  'Анализ неструктурированных данных',
#  'Сбор и обработка данных с помощью краудсорсинга',
#  'Безопасность компьютерных систем',
#  'Принятие решений в условиях риска и неопределённости',
#  'Теория баз данных',
#  'Байесовские методы машинного обучения',
#  'Statistical Learning Theory',
#  'Глубинное обучение в обработке звука']

# %%
def places(list_of_courses, list_of_places):
  for i in list_of_courses:
    if i == 'Statistical Learning Theory' or i == 'Высокопроизводительные вычисления':
      list_of_places.append(60)
    elif i == 'Анализ неструктурированных данных':
      list_of_places.append(-1)
    else:
      list_of_places.append(30)
  return list_of_places

# %%
list_of_places = []
list_of_places = places(list_of_courses, list_of_places)

# %% [markdown]
# Проверяю, что количество мест правильно соотносится с курсами:

# %%
for i in range(len(list_of_places)):
  print(list_of_courses[i], list_of_places[i])
# Out:
# Матричные вычисления 30
# Высокопроизводительные вычисления 60
# Моделирование временных рядов 30
# Язык SQL 30
# Анализ неструктурированных данных -1
# Сбор и обработка данных с помощью краудсорсинга 30
# Безопасность компьютерных систем 30
# Принятие решений в условиях риска и неопределённости 30
# Теория баз данных 30
# Байесовские методы машинного обучения 30
# Statistical Learning Theory 60
# Глубинное обучение в обработке звука 30

# %% [markdown]
# Действую также как и при реализации 1 волны на всех волнах, меняя только условие отбора тех, кто принимает участие в волне

# %%
#1 волна
for i in range(0, len(list_of_courses)):
  participants = pd.DataFrame(columns=["ID", 'percentile', 'course1'])
  participants['ID'] = df.loc[(df['fall_1'] == list_of_courses[i]) | ((df['17_group'].isin([171, 172, 173])) & (df['fall_2'] == list_of_courses[i]))
   | ((df['is_mi'] == 1) & (df['fall_2'] == list_of_courses[i]))]['id']
  participants['percentile'] = df.loc[(df['fall_1'] == list_of_courses[i]) | ((df['17_group'].isin([171, 172, 173])) & (df['fall_2'] == list_of_courses[i]))
   | ((df['is_mi'] == 1) & (df['fall_2'] == list_of_courses[i]))]['percentile']
  subject = list_of_courses[i]
  participants['course1'] = subject
  participants.drop_duplicates()
  participants.sort_values('percentile')
  if list_of_places[i] != -1:

    participants = participants.iloc[:list_of_places[i]]
    num = len(participants)
    res_fall.loc[(res_fall['ID'].isin(participants['ID'])) & (res_fall['course1'] != ('')) & (res_fall['course1'] != list_of_courses[i]), 'course2'] = participants['course1']
    res_fall.loc[(res_fall['ID'].isin(participants['ID'])) & (res_fall['course1'] == ('')), 'course1'] = participants['course1']

    list_of_places[i] -= num
  elif list_of_places[i] == -1:
    res_fall.loc[(res_fall['ID'].isin(participants['ID'])) & (res_fall['course1'] != ('')) & (res_fall['course1'] != list_of_courses[i]), 'course2'] = participants['course1']
    res_fall.loc[(res_fall['ID'].isin(participants['ID'])) & (res_fall['course1'] == ('')), 'course1'] = participants['course1']


res_fall
# Out:
#                                    ID  \
# 80   3e106aaef8b24dbb01319c73e14c2936
# 231  3a7326c9e355a67d3805824ca34c4bc5
# 91   e0ca1a9548af9a3f98428c62420aa484
# 273  7fe7df0d207babbf30249b3063ac1f26
# 19   86d929f6fd741e56e93cee5900298849
# ..                                ...
# 359  79d14db48e4737af731960ae212d5134
# 170  40b18d40197e3db66312a026e06b8ff1
# 128  be4fa2120de3397ae21eac38ff0060e3
# 340  d539461bf254cf8b3201cdf7990b119e
# 217  7a21ef645ecb42198be493dd65320e78
#
#                                                course1  \
# 80                    Безопасность компьютерных систем
# 231                  Высокопроизводительные вычисления
# 91                                Матричные вычисления
# 273                  Высокопроизводительные вычисления
# 19     Сбор и обработка данных с помощью краудсорсинга
# ..                                                 ...
# 359  Принятие решений в условиях риска и неопределё...
# 170
# 128
# ...

# %%
#2 волна
for i in range(0, len(list_of_courses)):
  participants = pd.DataFrame(columns=["ID", 'percentile', 'course1'])
  participants['ID'] = df.loc[((df['fall_2'] == list_of_courses[i]) & (res_fall['course1'] == '') & (((df['17_group'] != 171) & (df['17_group'] != 172)
                                                                                                     & (df['17_group'] != 173))| (df['is_mi'] == 0)))
  | ((df['17_group'].isin([171, 172, 173]))
   & (df['fall_3'] == list_of_courses[i]) & ((res_fall['course1'] == '') | ((res_fall['course1'] != list_of_courses[i]) & (res_fall['course2'] == '')))) | ((df['is_mi'] == 1) & (df['fall_3'] == list_of_courses[i])
   & ((res_fall['course1'] == '') | (res_fall['course2'] == '')))]['id']

  participants['percentile'] = df.loc[((df['fall_2'] == list_of_courses[i]) & (res_fall['course1'] == '') & (((df['17_group'] != 171) & (df['17_group'] != 172)
                                                                                                     & (df['17_group'] != 173))| (df['is_mi'] == 0)))
  | ((df['17_group'].isin([171, 172, 173]))
   & (df['fall_3'] == list_of_courses[i]) & ((res_fall['course1'] == '') | ((res_fall['course1'] != list_of_courses[i]) & (res_fall['course2'] == '')))) | ((df['is_mi'] == 1) & (df['fall_3'] == list_of_courses[i])
   & ((res_fall['course1'] == '') | (res_fall['course2'] == '')))]['percentile']


  subject = list_of_courses[i]
  participants['course1'] = subject

  participants.drop_duplicates()
  participants.sort_values('percentile')

  if list_of_places[i] != -1:
    if list_of_places[i] > 0:
      participants = participants.iloc[:list_of_places[i]]
      num = len(participants)

      res_fall.loc[(res_fall['ID'].isin(participants['ID'])) & (res_fall['course1'] != ('')) & (res_fall['course1'] != list_of_courses[i]), 'course2'] = participants['course1']
      res_fall.loc[(res_fall['ID'].isin(participants['ID'])) & (res_fall['course1'] == ('')), 'course1'] = participants['course1']

      list_of_places[i] -= num

  elif list_of_places[i] == -1:
    res_fall.loc[(res_fall['ID'].isin(participants['ID'])) & (res_fall['course1'] != ('')) & (res_fall['course1'] != list_of_courses[i]), 'course2'] = participants['course1']
    res_fall.loc[(res_fall['ID'].isin(participants['ID'])) & (res_fall['course1'] == ('')), 'course1'] = participants['course1']

# %%
#3 волна
for i in range(0, len(list_of_courses)):
  participants = pd.DataFrame(columns=["ID", 'percentile', 'course1'])
  participants['ID'] = df.loc[(df['fall_3'] == list_of_courses[i]) & (res_fall['course1'] == '')]['id']
  participants['percentile'] = df.loc[(df['fall_3'] == list_of_courses[i]) & (res_fall['course1'] == '')]['percentile']

  subject = list_of_courses[i]
  participants['course1'] = subject

  participants.drop_duplicates()
  participants.sort_values('percentile')

  if list_of_places[i] != -1:
    if list_of_places[i] > 0:
      participants = participants.iloc[:list_of_places[i]]
      num = len(participants)

      res_fall.loc[(res_fall['ID'].isin(participants['ID'])) & (res_fall['course1'] == ('')), 'course1'] = participants['course1']

      list_of_places[i] -= num

  elif list_of_places[i] == -1:
    res_fall.loc[(res_fall['ID'].isin(participants['ID'])) & (res_fall['course1'] == ('')), 'course1'] = participants['course1']

# %% [markdown]
# Делаю заполнение более эстетичным:

# %%
res_fall.loc[res_fall['course1'] == (''), 'course1'] = '???'
res_fall.loc[(res_fall['ID'].isin(df['id']))
& ((df['17_group'].isin([171, 172, 173])) | (df['is_mi'] == 1)) & (res_fall['course2'] == ('')), 'course2'] = '???'

res_fall.loc[(res_fall['ID'].isin(df['id']))
& ((df['17_group'].isin([171, 172, 173]) == False) | (df['is_mi'] == 0)) & (res_fall['course2'] == ('')), 'course2'] = '-'

# %%
res_fall.to_csv('res_fall.csv', index=None)

# %%
res_fall
# Out:
#                                    ID  \
# 80   3e106aaef8b24dbb01319c73e14c2936
# 231  3a7326c9e355a67d3805824ca34c4bc5
# 91   e0ca1a9548af9a3f98428c62420aa484
# 273  7fe7df0d207babbf30249b3063ac1f26
# 19   86d929f6fd741e56e93cee5900298849
# ..                                ...
# 359  79d14db48e4737af731960ae212d5134
# 170  40b18d40197e3db66312a026e06b8ff1
# 128  be4fa2120de3397ae21eac38ff0060e3
# 340  d539461bf254cf8b3201cdf7990b119e
# 217  7a21ef645ecb42198be493dd65320e78
#
#                                                course1  \
# 80                    Безопасность компьютерных систем
# 231                  Высокопроизводительные вычисления
# 91                                Матричные вычисления
# 273                  Высокопроизводительные вычисления
# 19     Сбор и обработка данных с помощью краудсорсинга
# ..                                                 ...
# 359  Принятие решений в условиях риска и неопределё...
# ...

# %% [markdown]
# **Отправьте свой файл res_fall.csv в контест (будет в ближайшее время, следите за новостями) и прикрепите/укажите ниже ваш никнейм и ссылку на успешную посылку.**

# %% [markdown]
# Ник: Елена Парфенюк
#
# https://contest.yandex.ru/contest/68637/problems/

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *Дисклеймер:*
#
# Успешная посылка в контесте является **обязательным** условием получения полного балла за этот (и следующий) пункт. Если добиться успешной посылки не удастся, баллы будут выставляться на усмотрение проверяюшего.
#
# При этом ОК в контесте не гарантирует полный балл. Оценка всё равно может быть снижена в случае обнаружения неэффективностей или ошибок в коде. Если вы сдадите в AnyTask очевидно неработающий код или ноутбук без кода, но при этом в контест будет сдан корректный файл, то это будет расцениваться как плагиат.

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_fall.csv в anytask

# %% [markdown]
# ### 4. [1 балла] Распределите таким же образом студентов еще и на весенние курсы по выбору.
#
# Если ваш код был хорошо структурирован, то это не составит проблем.
#
# Если вы выполнили это задание, сдайте среди прочего файл res_spring.csv в таком же формате, как и res_fall.csv.

# %%
df
# Out:
#                   timestamp                                id  rating  \
# 80  2020-05-18 17:09:23.589  3e106aaef8b24dbb01319c73e14c2936     784
# 231 2020-05-14 21:52:43.844  3a7326c9e355a67d3805824ca34c4bc5    1457
# 91  2020-05-18 18:03:57.347  e0ca1a9548af9a3f98428c62420aa484     764
# 273 2020-05-18 12:39:47.722  7fe7df0d207babbf30249b3063ac1f26    1365
# 19  2020-05-15 21:34:32.550  86d929f6fd741e56e93cee5900298849     761
# ..                      ...                               ...     ...
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 170 2020-05-18 22:29:14.162  40b18d40197e3db66312a026e06b8ff1     515
# 128 2020-05-18 21:12:00.134  be4fa2120de3397ae21eac38ff0060e3     502
# 340 2020-05-18 23:12:29.049  d539461bf254cf8b3201cdf7990b119e     964
# 217 2020-05-20 11:34:10.787  7a21ef645ecb42198be493dd65320e78     495
#
#      18_group  is_mi                                             fall_1  \
# ...

# %% [markdown]
# Сдвигаем курсы для студентов, обучающихся на моп и выбраших мо2 как кпв

# %%
df.loc[(df['17_group'].isin([171, 172])) & (df['spring_1'] == 'Машинное обучение 2'), 'spring_1'] = df['spring_2']
df.loc[(df['17_group'].isin([171, 172])) & (df['spring_1'] == 'Машинное обучение 2'), 'spring_2'] = df['spring_3']
df.loc[(df['17_group'].isin([171, 172])) & (df['spring_1'] == 'Машинное обучение 2'), 'spring_3'] = '???'

df.loc[(df['17_group'].isin([171, 172]) & (df['spring_2'] == 'Машинное обучение 2')), 'spring_2'] = df['spring_3']
df.loc[(df['17_group'].isin([171, 172]) & (df['spring_2'] == 'Машинное обучение 2')), 'spring_3'] = '???'

df.loc[(df['17_group'].isin([171, 172]) & (df['spring_3'] == 'Машинное обучение 2')), 'spring_3'] = '???'

# %%
df.loc[(df['18_group'] != 0) & (df['is_ml_student'] == 1.0) & (df['spring_1'] == 'Машинное обучение 2'), 'spring_1'] = df['spring_2']
df.loc[(df['18_group'] != 0) & (df['is_ml_student'] == 1.0) & (df['spring_1'] == 'Машинное обучение 2'), 'spring_2'] = df['spring_3']
df.loc[(df['18_group'] != 0) & (df['is_ml_student'] == 1.0) & (df['spring_1'] == 'Машинное обучение 2'), 'spring_3'] = '???'

df.loc[(df['18_group'] != 0) & (df['is_ml_student'] == 1.0) & (df['spring_2'] == 'Машинное обучение 2'), 'spring_2'] = df['spring_3']
df.loc[(df['18_group'] != 0) & (df['is_ml_student'] == 1.0) & (df['spring_2'] == 'Машинное обучение 2'), 'spring_3'] = '???'

df.loc[(df['18_group'] != 0) & (df['is_ml_student'] == 1.0) & (df['spring_3'] == 'Машинное обучение 2'), 'spring_3'] = '???'

# %%
res_spring = pd.DataFrame(columns=['ID', 'course1', 'course2'])
res_spring['ID'] = df['id']
res_spring['course1'] = ''
res_spring['course2'] = ''

# %%
df = df.sort_values('percentile')
list_of_courses_sp = df['spring_1'].tolist()
list_of_courses_sp = df['spring_2'].tolist()
list_of_courses_sp = list(set(list_of_courses_sp))
list_of_courses_sp
# Out:
# ['Промышленное программирование на языке Java',
#  'Компьютерные сети',
#  'Численные методы',
#  'Проектирование и разработка высоконагруженных сервисов',
#  'Дополнительные главы прикладной статистики',
#  'Машинное обучение 2',
#  'Конфликты и кооперация',
#  'Обучение с подкреплением',
#  'Анализ данных в бизнесе',
#  'Символьные вычисления',
#  'Генеративные модели в машинном обучении',
#  'Дискретная оптимизация',
#  'Методы сжатия и передачи медиаданных',
#  'Системы баз данных',
#  'Компьютерное зрение']

# %%
def places_sp(list_of_courses, list_of_places):
  for i in list_of_courses:
    if i == 'Обучение с подкреплением' or i == 'Анализ данных в бизнесе':
      list_of_places.append(60)
    else:
      list_of_places.append(30)
  return list_of_places

# %%
list_of_places_sp = []
list_of_places_sp = places_sp(list_of_courses_sp, list_of_places_sp)
list_of_places_sp
# Out:
# [30, 30, 30, 30, 30, 30, 30, 60, 60, 30, 30, 30, 30, 30, 30]

# %%
#1 волна
for i in range(0, len(list_of_courses_sp)):
  participants = pd.DataFrame(columns=["ID", 'percentile', 'course1'])
  participants['ID'] = df.loc[(df['spring_1'] == list_of_courses_sp[i]) | (df['17_group'].isin([171, 172, 173]) & (df['spring_2'] == list_of_courses_sp[i]))]['id']
  participants['percentile'] = df.loc[(df['spring_1'] == list_of_courses_sp[i]) | (df['17_group'].isin([171, 172, 173]) & (df['spring_2'] == list_of_courses_sp[i]))]['percentile']

  subject = list_of_courses_sp[i]
  participants['course1'] = subject
  participants.drop_duplicates()
  participants.sort_values('percentile')

  participants = participants.iloc[:list_of_places_sp[i]]
  num = len(participants)
  res_spring.loc[(res_spring['ID'].isin(participants['ID'])) & (res_spring['course1'] != ('')) & (res_spring['course1'] != list_of_courses_sp[i]), 'course2'] = participants['course1']
  res_spring.loc[(res_spring['ID'].isin(participants['ID'])) & (res_spring['course1'] == ('')), 'course1'] = participants['course1']
  list_of_places_sp[i] -= num

# %%
res_spring
# Out:
#                                    ID  \
# 80   3e106aaef8b24dbb01319c73e14c2936
# 231  3a7326c9e355a67d3805824ca34c4bc5
# 91   e0ca1a9548af9a3f98428c62420aa484
# 273  7fe7df0d207babbf30249b3063ac1f26
# 19   86d929f6fd741e56e93cee5900298849
# ..                                ...
# 359  79d14db48e4737af731960ae212d5134
# 170  40b18d40197e3db66312a026e06b8ff1
# 128  be4fa2120de3397ae21eac38ff0060e3
# 340  d539461bf254cf8b3201cdf7990b119e
# 217  7a21ef645ecb42198be493dd65320e78
#
#                                                course1                course2
# 80                              Дискретная оптимизация
# 231                                   Численные методы  Символьные вычисления
# 91                              Дискретная оптимизация
# 273  Проектирование и разработка высоконагруженных ...
# 19          Дополнительные главы прикладной статистики
# ..                                                 ...                    ...
# ...

# %%
#2 волна
for i in range(0, len(list_of_courses_sp)):
  participants = pd.DataFrame(columns=["ID", 'percentile', 'course1'])
  participants['ID'] = df.loc[((df['spring_2'] == list_of_courses_sp[i]) & (res_spring['course1'] == '') & (((df['17_group'] != 171) & (df['17_group'] != 172)
                                                                                                     & (df['17_group'] != 173))))
  | ((df['17_group'].isin([171, 172, 173]))
   & (df['spring_3'] == list_of_courses_sp[i]) & ((res_spring['course1'] == '') | ((res_spring['course1'] != list_of_courses_sp[i]) & (res_spring['course2'] == ''))))]['id']

  participants['percentile'] = df.loc[((df['spring_2'] == list_of_courses_sp[i]) & (res_spring['course1'] == '') & (((df['17_group'] != 171) & (df['17_group'] != 172)
                                                                                                     & (df['17_group'] != 173))))
  | ((df['17_group'].isin([171, 172, 173]))
   & (df['spring_3'] == list_of_courses_sp[i]) & ((res_spring['course1'] == '') | ((res_spring['course1'] != list_of_courses_sp[i]) & (res_spring['course2'] == ''))))]['percentile']



  subject = list_of_courses_sp[i]
  participants['course1'] = subject
  participants.drop_duplicates()
  participants.sort_values('percentile')

  participants = participants.iloc[:list_of_places_sp[i]]
  num = len(participants)
  res_spring.loc[(res_spring['ID'].isin(participants['ID'])) & (res_spring['course1'] != ('')) & (res_spring['course1'] != list_of_courses_sp[i]), 'course2'] = participants['course1']
  res_spring.loc[(res_spring['ID'].isin(participants['ID'])) & (res_spring['course1'] == ('')), 'course1'] = participants['course1']
  list_of_places_sp[i] -= num

# %%
res_spring
# Out:
#                                    ID  \
# 80   3e106aaef8b24dbb01319c73e14c2936
# 231  3a7326c9e355a67d3805824ca34c4bc5
# 91   e0ca1a9548af9a3f98428c62420aa484
# 273  7fe7df0d207babbf30249b3063ac1f26
# 19   86d929f6fd741e56e93cee5900298849
# ..                                ...
# 359  79d14db48e4737af731960ae212d5134
# 170  40b18d40197e3db66312a026e06b8ff1
# 128  be4fa2120de3397ae21eac38ff0060e3
# 340  d539461bf254cf8b3201cdf7990b119e
# 217  7a21ef645ecb42198be493dd65320e78
#
#                                                course1                course2
# 80                              Дискретная оптимизация
# 231                                   Численные методы  Символьные вычисления
# 91                              Дискретная оптимизация
# 273  Проектирование и разработка высоконагруженных ...
# 19          Дополнительные главы прикладной статистики
# ..                                                 ...                    ...
# ...

# %%
#3 волна
for i in range(0, len(list_of_courses_sp)):
  participants = pd.DataFrame(columns=["ID", 'percentile', 'course1'])
  participants['ID'] = df.loc[((df['spring_3'] == list_of_courses_sp[i]) & (res_spring['course1'] == '') & (((df['17_group'] != 171) & (df['17_group'] != 172)
                                                                                                     & (df['17_group'] != 173))))]['id']
  participants['percentile'] = df.loc[((df['spring_3'] == list_of_courses_sp[i]) & (res_spring['course1'] == '') & (((df['17_group'] != 171) & (df['17_group'] != 172)
                                                                                                     & (df['17_group'] != 173))))]['percentile']
  subject = list_of_courses_sp[i]
  participants['course1'] = subject
  participants.drop_duplicates()
  participants.sort_values('percentile')

  participants = participants.iloc[:list_of_places_sp[i]]
  num = len(participants)
  res_spring.loc[(res_spring['ID'].isin(participants['ID'])) & (res_spring['course1'] != ('')) & (res_spring['course1'] != list_of_courses_sp[i]), 'course2'] = participants['course1']
  res_spring.loc[(res_spring['ID'].isin(participants['ID'])) & (res_spring['course1'] == ('')), 'course1'] = participants['course1']
  list_of_places_sp[i] -= num

# %%
res_spring
# Out:
#                                    ID  \
# 80   3e106aaef8b24dbb01319c73e14c2936
# 231  3a7326c9e355a67d3805824ca34c4bc5
# 91   e0ca1a9548af9a3f98428c62420aa484
# 273  7fe7df0d207babbf30249b3063ac1f26
# 19   86d929f6fd741e56e93cee5900298849
# ..                                ...
# 359  79d14db48e4737af731960ae212d5134
# 170  40b18d40197e3db66312a026e06b8ff1
# 128  be4fa2120de3397ae21eac38ff0060e3
# 340  d539461bf254cf8b3201cdf7990b119e
# 217  7a21ef645ecb42198be493dd65320e78
#
#                                                course1                course2
# 80                              Дискретная оптимизация
# 231                                   Численные методы  Символьные вычисления
# 91                              Дискретная оптимизация
# 273  Проектирование и разработка высоконагруженных ...
# 19          Дополнительные главы прикладной статистики
# ..                                                 ...                    ...
# ...

# %%
res_spring.loc[res_spring['course1'] == (''), 'course1'] = '???'
res_spring.loc[(res_spring['ID'].isin(df['id']))
& ((df['17_group'].isin([171, 172, 173]))) & (res_spring['course2'] == ('')), 'course2'] = '???'

res_spring.loc[(res_spring['ID'].isin(df['id']))
& (((df['17_group'] != 171) & (df['17_group'] != 172) & (df['17_group'] != 173))) & (res_spring['course2'] == ('')), 'course2'] = '-'

# %%
res_spring
# Out:
#                                    ID  \
# 80   3e106aaef8b24dbb01319c73e14c2936
# 231  3a7326c9e355a67d3805824ca34c4bc5
# 91   e0ca1a9548af9a3f98428c62420aa484
# 273  7fe7df0d207babbf30249b3063ac1f26
# 19   86d929f6fd741e56e93cee5900298849
# ..                                ...
# 359  79d14db48e4737af731960ae212d5134
# 170  40b18d40197e3db66312a026e06b8ff1
# 128  be4fa2120de3397ae21eac38ff0060e3
# 340  d539461bf254cf8b3201cdf7990b119e
# 217  7a21ef645ecb42198be493dd65320e78
#
#                                                course1                course2
# 80                              Дискретная оптимизация                      -
# 231                                   Численные методы  Символьные вычисления
# 91                              Дискретная оптимизация                      -
# 273  Проектирование и разработка высоконагруженных ...                      -
# 19          Дополнительные главы прикладной статистики                      -
# ...

# %%
res_spring.to_csv('res_spring.csv', index=None)

# %% [markdown]
# **Отправьте свой файл res_spring.csv в контест (будет в ближайшее время, следите за новостями) и прикрепите/укажите ниже ваш никнейм и ссылку на успешную посылку.**

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_spring.csv в anytask

# %% [markdown]
# Вставьте картинку, описывающую ваш опыт выполнения этого задания:

# %% [markdown]
# ![image.png](data:image/png;base64,...)
